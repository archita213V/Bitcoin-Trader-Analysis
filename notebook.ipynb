# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load Dataset

# %%
trader = pd.read_csv("data/historical_data.csv")
fear_greed = pd.read_csv("data/fear_greed_index.csv")

# %%
trader.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
fear_greed.head()
# Out:
#     timestamp  value classification        date
# 0  1517463000     30           Fear  2018-02-01
# 1  1517549400     15   Extreme Fear  2018-02-02
# 2  1517635800     40           Fear  2018-02-03
# 3  1517722200     24   Extreme Fear  2018-02-04
# 4  1517808600     11   Extreme Fear  2018-02-05

# %%
trader.shape
# Out:
# (211224, 16)

# %%
fear_greed.shape
# Out:
# (2644, 4)

# %% [markdown]
# Dataset Columns

# %%
trader.columns
# Out:
# Index(['Account', 'Coin', 'Execution Price', 'Size Tokens', 'Size USD', 'Side',
#        'Timestamp IST', 'Start Position', 'Direction', 'Closed PnL',
#        'Transaction Hash', 'Order ID', 'Crossed', 'Fee', 'Trade ID',
#        'Timestamp'],
#       dtype='object')

# %%
fear_greed.columns
# Out:
# Index(['timestamp', 'value', 'classification', 'date'], dtype='object')

# %% [markdown]
# Missing Values

# %%
trader.isnull().sum()
# Out:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# dtype: int64

# %%
fear_greed.isnull().sum()
# Out:
# timestamp         0
# value             0
# classification    0
# date              0
# dtype: int64

# %% [markdown]
# Dataset Information

# %%
trader.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
fear_greed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   int64
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 82.8+ KB

# %% [markdown]
# Statistcal Summary

# %%
trader.describe()
# Out:
#        Execution Price   Size Tokens      Size USD  Start Position  \
# count    211224.000000  2.112240e+05  2.112240e+05    2.112240e+05
# mean      11414.723350  4.623365e+03  5.639451e+03   -2.994625e+04
# std       29447.654868  1.042729e+05  3.657514e+04    6.738074e+05
# min           0.000005  8.740000e-07  0.000000e+00   -1.433463e+07
# 25%           4.854700  2.940000e+00  1.937900e+02   -3.762311e+02
# 50%          18.280000  3.200000e+01  5.970450e+02    8.472793e+01
# 75%         101.580000  1.879025e+02  2.058960e+03    9.337278e+03
# max      109004.000000  1.582244e+07  3.921431e+06    3.050948e+07
#
#           Closed PnL      Order ID            Fee      Trade ID     Timestamp
# count  211224.000000  2.112240e+05  211224.000000  2.112240e+05  2.112240e+05
# mean       48.749001  6.965388e+10       1.163967  5.628549e+14  1.737744e+12
# std       919.164828  1.835753e+10       6.758854  3.257565e+14  8.689920e+09
# ...

# %%
fear_greed.describe()
# Out:
#           timestamp        value
# count  2.644000e+03  2644.000000
# mean   1.631899e+09    46.981089
# std    6.597967e+07    21.827680
# min    1.517463e+09     5.000000
# 25%    1.574811e+09    28.000000
# 50%    1.631900e+09    46.000000
# 75%    1.688989e+09    66.000000
# max    1.746164e+09    95.000000

# %% [markdown]
# Duplicate Values

# %%
trader.duplicated().sum()
# Out:
# np.int64(0)

# %%
fear_greed.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Data Cleaning

# %% [markdown]
# Check Datatype

# %%
trader.dtypes
# Out:
# Account              object
# Coin                 object
# Execution Price     float64
# Size Tokens         float64
# Size USD            float64
# Side                 object
# Timestamp IST        object
# Start Position      float64
# Direction            object
# Closed PnL          float64
# Transaction Hash     object
# Order ID              int64
# Crossed                bool
# Fee                 float64
# Trade ID            float64
# Timestamp           float64
# dtype: object

# %%
fear_greed.dtypes
# Out:
# timestamp          int64
# value              int64
# classification    object
# date              object
# dtype: object

# %% [markdown]
# Convert Datatype

# %%
trader['Timestamp IST']=pd.to_datetime(trader['Timestamp IST'],format='%d-%m-%Y %H:%M')

# %%
trader['Timestamp']=pd.to_datetime(trader['Timestamp'])

# %%
trader.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
fear_greed['timestamp']=pd.to_datetime(fear_greed["timestamp"])

# %%
fear_greed['date']=pd.to_datetime(fear_greed['date'])

# %%
fear_greed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       2644 non-null   datetime64[ns]
#  1   value           2644 non-null   int64
#  2   classification  2644 non-null   object
#  3   date            2644 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(1)
# memory usage: 82.8+ KB

# %% [markdown]
# Feature Engineering(Create Date column in trader dataset to merge both the dataset)

# %%
trader['date'] = pd.to_datetime(trader['Timestamp IST']).dt.date

# %%
trader.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
trader['date']=pd.to_datetime(trader['date'])

# %%
trader.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %% [markdown]
# Merging(Merge Both the Datasey by using date column because it common in both

# %%
merged = pd.merge(
    trader,
    fear_greed,
    on="date",
    how="left"
)

# %%
merged.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side       Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY 2024-12-02 22:50:00        0.000000       Buy
# 1        16.00    127.68  BUY 2024-12-02 22:50:00      986.524596       Buy
# 2       144.09   1150.63  BUY 2024-12-02 22:50:00     1002.518996       Buy
# 3       142.98   1142.04  BUY 2024-12-02 22:50:00     1146.558564       Buy
# 4         8.73     69.75  BUY 2024-12-02 22:50:00     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %%
merged.shape
# Out:
# (211224, 20)

# %%
merged.describe()
# Out:
#        Execution Price   Size Tokens      Size USD  \
# count    211224.000000  2.112240e+05  2.112240e+05
# mean      11414.723350  4.623365e+03  5.639451e+03
# min           0.000005  8.740000e-07  0.000000e+00
# 25%           4.854700  2.940000e+00  1.937900e+02
# 50%          18.280000  3.200000e+01  5.970450e+02
# 75%         101.580000  1.879025e+02  2.058960e+03
# max      109004.000000  1.582244e+07  3.921431e+06
# std       29447.654868  1.042729e+05  3.657514e+04
#
#                        Timestamp IST  Start Position     Closed PnL  \
# count                         211224    2.112240e+05  211224.000000
# mean   2025-01-31 12:04:22.915009792   -2.994625e+04      48.749001
# min              2023-05-01 01:06:00   -1.433463e+07 -117990.104100
# 25%              2024-12-31 21:00:45   -3.762311e+02       0.000000
# 50%              2025-02-24 18:55:00    8.472793e+01       0.000000
# 75%              2025-04-02 18:22:00    9.337278e+03       5.792797
# ...

# %%
merged.isnull().sum()
# Out:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# date                0
# timestamp           6
# value               6
# classification      6
# dtype: int64

# %% [markdown]
# Save merged Dataset

# %%
merged.to_csv("data/merged_dataset.csv", index=False)

# %% [markdown]
# EDA(Exploratory Data Analysis)

# %% [markdown]
# ### 1 Objective
# To analyze how trader profitability (Closed PnL) varies across different Fear & Greed market categories.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=merged,
    x='classification',
    y='Closed PnL',color='green'
)
plt.title("Closed PnL by Fear & Greed Category")
plt.savefig("graphs/graph1.png")
plt.show()

# %%
profit = merged.groupby("classification")["Closed PnL"].mean()
profit.plot(kind='bar', figsize=(8,5), color='green')
plt.title("Average Profit by Fear & Greed Category")
plt.ylabel("Average Closed PnL")
plt.savefig("graphs/graph2.png")
plt.show()

# %% [markdown]
# ### 3 Objective
# To analyze how frequently each Fear & Greed market category appears in the dataset.

# %%
sns.countplot(data=merged,x='classification',color='blue')
plt.title("Distribution of Fear & Greed Categories")
plt.xlabel("classification")
plt.ylabel("Number of Records")
plt.savefig("graphs/graph3.png")
plt.show()

# %%
volume = merged.groupby("classification")["Size USD"].sum()
volume.plot(kind="bar", color="green", figsize=(8,5))
plt.title("Trading Volume by Fear & Greed Category")
plt.ylabel("USD")
plt.savefig("graphs/graph4.png")
plt.show()

# %%
sns.countplot(
    data=merged,
    x='classification',
    hue='Side'
)
plt.title("Buy vs Sell Across Fear & Greed Categories")
plt.xlabel("classification")
plt.ylabel("Number of Trades")
plt.savefig("graphs/graph5.png")
plt.show()

# %%
merged['Coin'].value_counts().head(10).plot(
    kind='bar',
    figsize=(10,5),
    color='orange'
)
plt.title("Top 10 Most Traded Coins")
plt.savefig("graphs/graph6.png")
plt.show()

# %%
sns.histplot(
    merged["Closed PnL"],
    bins=40,
    kde=True
)
plt.title("Distribution of Closed PnL")
plt.savefig("graphs/graph7.png")
plt.show()

# %%
merged['Hour']=merged['Timestamp IST'].dt.hour
merged.groupby("Hour").size().plot(
    figsize=(8,5)
)
plt.title("Hourly Trading Activity")
plt.xlabel("Hour of the Day")
plt.ylabel("Number of Trades")
plt.savefig("graphs/graph8.png")
plt.show()

# %%
merged["Trade Result"] = merged["Closed PnL"].apply(
    lambda x: "Profit" if x > 0 else "Loss"
)
sns.countplot(data=merged, x="Trade Result")
plt.title("Winning vs Losing Trades")
plt.xlabel("Trade Result")
plt.ylabel("Number of Trades")
plt.savefig("graphs/graph9.png")
plt.show()

# %%
plt.figure(figsize=(10,8))
corr = merged.select_dtypes(include='number').corr()
sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)
plt.title("Correlation Heatmap")
plt.savefig("graphs/graph10.png")
plt.show()

# %%
merged["classification"].value_counts()
# Out:
# classification
# Fear             61837
# Greed            50303
# Extreme Greed    39992
# Neutral          37686
# Extreme Fear     21400
# Name: count, dtype: int64

# %%
merged.groupby("classification")["Closed PnL"].mean()
# Out:
# classification
# Extreme Fear     34.537862
# Extreme Greed    67.892861
# Fear             54.290400
# Greed            42.743559
# Neutral          34.307718
# Name: Closed PnL, dtype: float64

# %%
merged.groupby("classification")["Size USD"].sum().round(2)
# Out:
# classification
# Extreme Fear     1.144843e+08
# Extreme Greed    1.244652e+08
# Fear             4.833248e+08
# Greed            2.885825e+08
# Neutral          1.802421e+08
# Name: Size USD, dtype: float64

# %%
merged["Trade Result"].value_counts()
# Out:
# Trade Result
# Loss      124355
# Profit     86869
# Name: count, dtype: int64

# %%
merged["Coin"].value_counts().head(10)
# Out:
# Coin
# HYPE         68005
# @107         29992
# BTC          26064
# ETH          11158
# SOL          10691
# FARTCOIN      4650
# MELANIA       4428
# PURR/USDC     2774
# WLD           1983
# SUI           1979
# Name: count, dtype: int64
